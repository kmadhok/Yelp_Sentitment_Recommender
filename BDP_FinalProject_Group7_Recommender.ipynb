# %% [markdown]
# #### Yelp Recommender

# %%
from pyspark.sql import SparkSession 

spark = SparkSession.builder.appName('Yelp Restaurant Recommender').getOrCreate()
sc = spark.sparkContext

# %%
# read in yelp datasets 
dfBusiness = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/business.snappy.parquet')
dfReview = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/review.snappy.parquet')
dfUser = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/user.snappy.parquet') 

# read in Daisuke's sentiment analysis model output 
dfSentiment = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/aspect_sentiment.snappy.parquet')

# %%
from pyspark.sql import functions as F 

# create partition function from professor 
def displayPartitions(df): 
    num = df.rdd.getNumPartitions() 
    df.withColumn('partitionId', F.spark_partition_id()).groupby('partitionId').count().orderBy(F.asc('count')).show(num)

# %% [raw]
# # clean business data
#
# # unwrap nested struct columns
#
# dfBusiness = dfBusiness.withColumn('AcceptsInsurance', F.col('attributes.AcceptsInsurance'))
# dfBusiness = dfBusiness.withColumn('AgesAllowed', F.col('attributes.AgesAllowed'))
# dfBusiness = dfBusiness.withColumn('Alcohol', F.col('attributes.Alcohol'))
# dfBusiness = dfBusiness.withColumn('Ambience', F.col('attributes.Ambience'))
# dfBusiness = dfBusiness.withColumn('BYOB', F.col('attributes.BYOB'))
# dfBusiness = dfBusiness.withColumn('BYOBCorkage', F.col('attributes.BYOBCorkage'))
# dfBusiness = dfBusiness.withColumn('BestNights', F.col('attributes.BestNights'))
# dfBusiness = dfBusiness.withColumn('BikeParking', F.col('attributes.BikeParking'))
# dfBusiness = dfBusiness.withColumn('BusinessAcceptsBitcoin', F.col('attributes.BusinessAcceptsBitcoin'))
# dfBusiness = dfBusiness.withColumn('BusinessAcceptsCreditCards', F.col('attributes.BusinessAcceptsCreditCards'))
# dfBusiness = dfBusiness.withColumn('BusinessParking', F.col('attributes.BusinessParking'))
# dfBusiness = dfBusiness.withColumn('ByAppointmentOnly', F.col('attributes.ByAppointmentOnly'))
# dfBusiness = dfBusiness.withColumn('Caters', F.col('attributes.Caters'))
# dfBusiness = dfBusiness.withColumn('CoatCheck', F.col('attributes.CoatCheck'))
# dfBusiness = dfBusiness.withColumn('Corkage', F.col('attributes.Corkage'))
# dfBusiness = dfBusiness.withColumn('DietaryRestrictions', F.col('attributes.DietaryRestrictions'))
# dfBusiness = dfBusiness.withColumn('DogsAllowed', F.col('attributes.DogsAllowed'))
# dfBusiness = dfBusiness.withColumn('DriveThru', F.col('attributes.DriveThru'))
# dfBusiness = dfBusiness.withColumn('GoodForDancing', F.col('attributes.GoodForDancing'))
# dfBusiness = dfBusiness.withColumn('GoodForKids', F.col('attributes.GoodForKids'))
# dfBusiness = dfBusiness.withColumn('GoodForMeal', F.col('attributes.GoodForMeal'))
# dfBusiness = dfBusiness.withColumn('HairSpecializesIn', F.col('attributes.HairSpecializesIn'))
# dfBusiness = dfBusiness.withColumn('HappyHour', F.col('attributes.HappyHour'))
# dfBusiness = dfBusiness.withColumn('HasTV', F.col('attributes.HasTV'))
# dfBusiness = dfBusiness.withColumn('Music', F.col('attributes.Music'))
# dfBusiness = dfBusiness.withColumn('NoiseLevel', F.col('attributes.NoiseLevel'))
# dfBusiness = dfBusiness.withColumn('Open24Hours', F.col('attributes.Open24Hours'))
# dfBusiness = dfBusiness.withColumn('OutdoorSeating', F.col('attributes.OutdoorSeating'))
# dfBusiness = dfBusiness.withColumn('RestaurantsAttire', F.col('attributes.RestaurantsAttire'))
# dfBusiness = dfBusiness.withColumn('RestaurantsCounterService', F.col('attributes.RestaurantsCounterService'))
# dfBusiness = dfBusiness.withColumn('RestaurantsDelivery', F.col('attributes.RestaurantsDelivery'))
# dfBusiness = dfBusiness.withColumn('RestaurantsGoodForGroups', F.col('attributes.RestaurantsGoodForGroups'))
# dfBusiness = dfBusiness.withColumn('RestaurantsPriceRange2', F.col('attributes.RestaurantsPriceRange2'))
# dfBusiness = dfBusiness.withColumn('RestaurantsReservations', F.col('attributes.RestaurantsReservations'))
# dfBusiness = dfBusiness.withColumn('RestaurantsTableService', F.col('attributes.RestaurantsTableService'))
# dfBusiness = dfBusiness.withColumn('RestaurantsTakeOut', F.col('attributes.RestaurantsTakeOut'))
# dfBusiness = dfBusiness.withColumn('Smoking', F.col('attributes.Smoking'))
# dfBusiness = dfBusiness.withColumn('WheelchairAccessible', F.col('attributes.WheelchairAccessible'))
# dfBusiness = dfBusiness.withColumn('WiFi', F.col('attributes.WiFi'))
#
# dfBusiness = dfBusiness.withColumn('Friday', F.col('hours.Friday'))
# dfBusiness = dfBusiness.withColumn('Monday', F.col('hours.Monday'))
# dfBusiness = dfBusiness.withColumn('Saturday', F.col('hours.Saturday'))
# dfBusiness = dfBusiness.withColumn('Sunday', F.col('hours.Sunday'))
# dfBusiness = dfBusiness.withColumn('Thursday', F.col('hours.Thursday'))
# dfBusiness = dfBusiness.withColumn('Tuesday', F.col('hours.Tuesday'))
# dfBusiness = dfBusiness.withColumn('Wednesday', F.col('hours.Wednesday'))
#
# dfBusiness = dfBusiness.drop('attributes', 'hours')

# %%
from pyspark.sql.functions import col, desc, when, regexp_replace, regexp_extract, explode 
from pyspark.sql.types import StringType, MapType, IntegerType 
from ast import literal_eval 

# clean business data (cont.) 

# drop any unnecessary fields 
dfBusiness = dfBusiness.drop('AcceptsInsurance', 'HairSpecializesIn')

# for each newly created column show the top distinct values and make necessary adjustments 
# for colName in dfBusiness.columns[12:]: 
    # dfBusiness.groupby(colName).count().withColumnRenamed('count', 'businesses').sort(col('businesses').desc()).show(25) 


# convert different string types to same value 
for column in ['AgesAllowed', 'Alcohol', 'BYOBCorkage', 'NoiseLevel', 'RestaurantsAttire', 'Smoking', 'WiFi']: 
    dfBusiness = dfBusiness.withColumn(column, regexp_replace(column, "u'", "'")) 

# convert any None or null to unknown 
dfBusiness = dfBusiness.replace('None', None) 
dfBusiness = dfBusiness.na.fill('unknown') 

# unnest further nested columns 
dfBusinessNestedCols = ['Ambience', 'BestNights', 'BusinessParking', 'DietaryRestrictions', 'GoodForMeal', 'Music'] 
for column in dfBusinessNestedCols: 
    dfBusiness = dfBusiness.withColumn('clean{}'.format(column), regexp_replace(column, "u'", "'")) 
    dfBusiness = dfBusiness.withColumn('clean{}'.format(column), regexp_replace(column, 'unknown', "{'unknown': True}")) 
    dfBusiness = dfBusiness.withColumn(column, F.udf(literal_eval, 'map<string,string>')('clean{}'.format(column))) 
    dfBusiness = dfBusiness.drop('clean{}'.format(column)) 
    curKeys = (dfBusiness.select(explode(column)).select('key').distinct().rdd.flatMap(lambda x: x).collect()) 
    curExpressions = [col(column).getItem(k).alias('{}_{}'.format(column, k)) for k in curKeys] 
    dfBusiness = dfBusiness.select('*', *curExpressions).drop(column) 

# create open/close for each time 
dfBusinessHoursCols = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'] 
for column in dfBusinessHoursCols: 
    dfBusiness = dfBusiness.select('*', F.when(col(column) != 'unknown', regexp_extract(column, r'.*?(?=\:)', 0)).otherwise(None).alias('{}_start_str'.format(column)))
    dfBusiness = dfBusiness.select('*', F.when(col(column) != 'unknown', regexp_extract(column, r'(?<=\-).+(?=\:)', 0)).otherwise(None).alias('{}_end_str'.format(column)))
    dfBusiness = dfBusiness.withColumn('{}_start'.format(column), col('{}_start_str'.format(column)).cast(IntegerType())) 
    dfBusiness = dfBusiness.withColumn('{}_end'.format(column), col('{}_end_str'.format(column)).cast(IntegerType()))
    dfBusiness = dfBusiness.drop(column, '{}_start_str'.format(column), '{}_end_str'.format(column)) 

# dfBusiness.printSchema()

# %%
# clean reviews data 

from pyspark.sql.functions import col, to_date, to_timestamp 
from pyspark.sql.functions import year, month, dayofweek, hour 
from pyspark.sql.functions import length 

# convert date field to actual date 
dfReview = dfReview.withColumn('datetime', to_timestamp(col('date'), 'yyyy-MM-dd HH:mm:ss')) 
dfReview = dfReview.withColumn('date', to_date(col('datetime'))) 

# create date-related fields 
dfReview = dfReview.withColumn('year', year(col('date'))).withColumn('month', month(col('date'))) 
dfReview = dfReview.withColumn('day', dayofweek(col('date'))) 
dfReview = dfReview.withColumn('hour', hour(col('datetime'))) 

# create length of review field 
dfReview = dfReview.withColumn('text_length', length(col('text'))) 

# dfReview.printSchema()

# %%
from pyspark.sql.functions import size, split 

# clean user data 

dfUser = dfUser.withColumn('yelping_since', to_timestamp(col('yelping_since'), 'yyyy-MM-dd HH:mm:ss')) 

dfUser = dfUser.replace('None', None) 
dfUser = dfUser.na.fill('unknown') 
dfUser = dfUser.withColumn('n_friends', F.when(col('friends') == 'unknown', 0).otherwise(size(split(col('friends'), r'\,'))))
dfUser = dfUser.drop('name', 'friends') 

# dfUser.show(5)

# %%
# clean sentiment data 

# confirm counts are similar between sentiment and review 
dfSentiment.count() # 3773770
dfReview.count() # 3773770 
# good! 

# dfSentiment.show(5, truncate = False) # already good thanks to Daisuke!

# %%
# repartition if necessary 

print('Default parallelism:', sc.defaultParallelism, '\n')

print('Number of dfBusiness partitions:', dfBusiness.rdd.getNumPartitions()) 
print('Number of dfReview partitions:', dfReview.rdd.getNumPartitions()) 
print('Number of dfSentiment partitions:', dfSentiment.rdd.getNumPartitions()) 
print('Number of dfUser partitions:', dfUser.rdd.getNumPartitions()) 

# good for now, but will want to repartition the final table

# %%
import numpy as np 

# rename the columns in each table and join together 

dfBusinessColumns = [str(np.where(col[-3:] != '_id', 'b_{}'.format(col), col)) for col in dfBusiness.columns] 
dfBusiness = dfBusiness.toDF(*dfBusinessColumns) 
dfReviewColumns = [str(np.where(col[-3:] != '_id', 'r_{}'.format(col), col)) for col in dfReview.columns]
dfReview = dfReview.toDF(*dfReviewColumns) 
dfSentimentColumns = [str(np.where(col[-3:] != '_id', 's_{}'.format(col), col)) for col in dfSentiment.columns]
dfSentiment = dfSentiment.toDF(*dfSentimentColumns) 
dfUserColumns = [str(np.where(col[-3:] != '_id', 'u_{}'.format(col), col)) for col in dfUser.columns]
dfUser = dfUser.toDF(*dfUserColumns) 

dfFinal = dfReview.join(dfBusiness, 'business_id', 'left').join(dfSentiment, 'review_id', 'left').join(dfUser, 'user_id', 'left') 

# dfFinal.printSchema()

# %%
# repartition the dataset 

print('Default parallelism:', sc.defaultParallelism, '\n')
print('Number of dfFinal partitions:', dfFinal.rdd.getNumPartitions(), '\n') 

dfFinal = dfFinal.repartition(200)
# displayPartitions(dfFinal) 

# consider creating additional features at a later point
# Out:
# Default parallelism: 4
# [Stage 28:=======================================================>(87 + 1) / 88]
# Number of dfFinal partitions: 85

# %%
del dfBusiness, dfReview, dfSentiment, dfUser

# %%
from pyspark.sql.functions import collect_set 
from pyspark.ml.fpm import FPGrowth 

# mine frequent user-business combinations 

dfAssocUb = dfFinal.select('b_name', 'user_id') 
dfAssocUb = dfAssocUb.groupBy('user_id').agg(collect_set('b_name').alias('businesses')) 
# dfAssocUb.show(5) 

# count users, businesses, and ratio 
print('# users:', dfAssocUb.count())
print('# businesses:', dfFinal.select('b_name').distinct().count())
print('# reviews:', dfFinal.count()) 
# seems like the 0.0001 should be a good support level as 0.001 won't return too many records 

# fit with higher min support to minimize size of output and get strongest associations 
fpgUb = FPGrowth(itemsCol = 'businesses', minSupport = 0.0001, minConfidence = 0) 
modelFpgUb = fpgUb.fit(dfAssocUb) 
dfFreqItemsets = modelFpgUb.freqItemsets.withColumnRenamed('items', 'businesses') 
print('# itemsets:', dfFreqItemsets.count()) 
dfFreqItemsets.filter('size(businesses) > 1').orderBy('freq', ascending = False).show(truncate = False) 

# identify any association rules 
dfAssocUbRules = modelFpgUb.associationRules.orderBy('confidence', ascending = False) 
dfAssocUbRules.show(truncate = False) 

# summarize the consequents 
dfAssocUbRecommendations = modelFpgUb.transform(dfAssocUb).filter(F.size(F.col('prediction')) >= 1) 
dfAssocUbRecommendations = dfAssocUbRecommendations.select('user_id', 'businesses', explode(dfAssocUbRecommendations.prediction)).withColumnRenamed('col', 'Recommendation') 
dfAssocUbRecommendations.show() 

# takeaways: 
# clear geographic tendencies (Pat's and Geno's in Philly), (Biscuit Love and Hattie B's in Nashville) 
# others are clearly fast food/global restaurants

# %% [raw]
# # mine frequent business-user combinations
#
# dfAssocBu = dfFinal.select('b_name', 'user_id')
# dfAssocBu = dfAssocBu.groupBy('b_name').agg(collect_set('user_id').alias('users'))
# # dfAssocBu.show(5)
#
# # fit with higher min support to minimize size of output and get strongest associations
# fpgBu = FPGrowth(itemsCol = 'users', minSupport = 0.0025, minConfidence = 0)
# modelFpgBu = fpgBu.fit(dfAssocBu)
# dfFreqItemsets = modelFpgBu.freqItemsets.withColumnRenamed('items', 'users')
# print('# itemsets:', dfFreqItemsets.count())
# dfFreqItemsets.filter('size(users) > 1').orderBy('freq', ascending = False).show(truncate = False)
#
# # identify any association rules
# dfAssocBuRules = modelFpgBu.associationRules.orderBy('confidence', ascending = False)
# dfAssocBuRules.show(truncate = False)
#
# # summarize the consequents
# dfAssocBuRecommendations = modelFpgBu.transform(dfAssocBu).filter(F.size(F.col('prediction')) >= 1)
# dfAssocBuRecommendations = dfAssocBuRecommendations.select('b_name', 'users', explode(dfAssocBuRecommendations.prediction)).withColumnRenamed('col', 'Recommendation')
# dfAssocBuRecommendations.show()
#
# # takeaways:
# # clear geographic tendencies (Pat's and Geno's in Philly), (Biscuit Love and Hattie B's in Nashville)
# # others are clearly fast food/global restaurants

# %%
from pyspark.ml.feature import StringIndexer
from datetime import datetime 
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator 

# create indexed dataframe 
dfALS = dfFinal.select('user_id', 'b_name', 'r_stars') 
for column in ['user_id', 'b_name']: 
    indexer = StringIndexer(inputCol = column, outputCol = 'idx_{}'.format(column)) 
    dfALS = indexer.fit(dfALS).transform(dfALS) 

# build a simple recommendation engine and tune the parameters effectively 
def modelALS(data, user, item, rating, sampleProp = 0.05, seedSamp = 1234, splitProp = 0.8, seedSplit = 5678, iters = 10, rank = 10, reg = 0.01, coldStart = 'drop', nonNeg = True): 
    samp = data.sample(sampleProp, seed = seedSamp) 
    train, test = samp.randomSplit([splitProp, (1-splitProp)]) 
    mod = ALS(maxIter = iters, regParam = reg, rank = rank, userCol = user, itemCol = item, ratingCol = rating, coldStartStrategy = coldStart, nonnegative = nonNeg) 
    modFit = mod.fit(train) 
    modPreds = modFit.transform(test) 
    evaluator = RegressionEvaluator(metricName = 'rmse', labelCol = 'r_stars') 
    rmse = evaluator.evaluate(modPreds) 
    # evaluator.evaluate(modPreds, {evaluator.metricName: "accuracy"})
    return modFit, modPreds, rmse 

# run one iteration 
# start = datetime.now() 
# fit1, preds1, rmse1 = modelALS(dfALS, 'idx_user_id', 'idx_b_name', 'r_stars') 
# print('Model fit in:', datetime.now()-start)

# %%
# evaluate initial fit 
# print('RMSE:', rmse1)

# %%
import itertools 

# create a grid searching fit 
iters = [5, 10, 20] 
regs = [0.01, 0.1] 
ranks = [5, 10, 20] 
grid = [el for el in itertools.product(iters, regs, ranks)]

# iteratively fit the model over the function below 
# will train on very small subset of the data (2%) to improve runtimes 
lOutput = [] 
for i, rg, rk in grid: 
    start = datetime.now() 
    print('Iteration with {} iterations, {} regularization parameter, and {} rank started at {}'.format(i, rg, rk, start)) 
    curFit, curPreds, curRMSE = modelALS(dfALS, 'idx_user_id', 'idx_b_name', 'r_stars', sampleProp = 0.02, iters = i, rank = rk, reg = rg) 
    lOutput.append((curFit, curPreds, i, rk, rg, curRMSE)) 
    print('Iteration completed in:', datetime.now()-start) 
    print('RMSE:', curRMSE)
# Out:
# Iteration with 5 iterations, 0.01 regularization parameter, and 5 rank started at 2023-05-18 04:17:01.223670
# 23/05/18 04:17:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:17:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:17:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:18:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:19:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:20:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:24.395951
# RMSE: 4.771131906795268
# Iteration with 5 iterations, 0.01 regularization parameter, and 10 rank started at 2023-05-18 04:20:25.619723
# 23/05/18 04:20:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:20:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:21:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:21:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:21:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:22:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:23:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:23:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:16.165201
# RMSE: 2.986872199813267
# Iteration with 5 iterations, 0.01 regularization parameter, and 20 rank started at 2023-05-18 04:23:41.785005
# 23/05/18 04:24:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:24:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:24:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:25:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:25:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:25:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:25:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:26:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:27:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:27:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:27:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:27:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:27:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:27:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:04:17.139216
# RMSE: 2.4237914716253877
# Iteration with 5 iterations, 0.1 regularization parameter, and 5 rank started at 2023-05-18 04:27:58.924319
# 23/05/18 04:28:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:28:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:28:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:29:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:30:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:31:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:07.473448
# RMSE: 2.3900637519277295
# Iteration with 5 iterations, 0.1 regularization parameter, and 10 rank started at 2023-05-18 04:31:06.397881
# 23/05/18 04:31:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:31:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:32:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:33:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:34:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:34:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:18.564725
# RMSE: 2.314528139754796
# Iteration with 5 iterations, 0.1 regularization parameter, and 20 rank started at 2023-05-18 04:34:24.962695
# 23/05/18 04:34:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:35:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:35:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:35:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:35:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:36:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:37:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:37:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:16.462479
# RMSE: 2.3103115484588073
# Iteration with 10 iterations, 0.01 regularization parameter, and 5 rank started at 2023-05-18 04:37:41.425253
# 23/05/18 04:38:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:38:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:38:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:38:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:38:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:39:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:40:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:41:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:42.691843
# RMSE: 3.5876645090493025
# Iteration with 10 iterations, 0.01 regularization parameter, and 10 rank started at 2023-05-18 04:41:24.117176
# 23/05/18 04:41:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:42:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:42:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:42:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:42:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:43:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:44:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:45:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:51.648325
# RMSE: 2.7376874848211012
# Iteration with 10 iterations, 0.01 regularization parameter, and 20 rank started at 2023-05-18 04:45:15.765618
# 23/05/18 04:45:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:45:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:46:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:46:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:46:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:46:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:47:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:48:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:48:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:45.251473
# RMSE: 2.375280468596678
# Iteration with 10 iterations, 0.1 regularization parameter, and 5 rank started at 2023-05-18 04:49:01.017181
# 23/05/18 04:49:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:49:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:50:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:51:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:52:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:52:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:52:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:52:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:53:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:53:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:54:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:54:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:54:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:54:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:54:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:55:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:56:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:57:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 04:57:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:04:53.328286
# RMSE: 2.2215463964345123
# Iteration with 10 iterations, 0.1 regularization parameter, and 20 rank started at 2023-05-18 04:57:38.062252
# 23/05/18 04:58:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:58:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:58:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:58:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 04:59:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:00:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:01:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:03:44.742503
# RMSE: 2.189806000652578
# Iteration with 20 iterations, 0.01 regularization parameter, and 5 rank started at 2023-05-18 05:01:22.804843
# 23/05/18 05:01:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:02:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:02:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:03:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:04:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:05:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:06:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:07:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:07:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:07:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:07:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:07:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:07:26 WARN org.apache.spark.scheduler.TaskSetManager: Lost task 4.0 in stage 1829.0 (TID 16820) (hub-hub-msca-bdp-dphub-student-mbecker-w-2.c.msca-bdp-student-ap.internal executor 3): java.lang.StackOverflowError
# 	at java.io.ObjectStreamClass.newInstance(ObjectStreamClass.java:1102)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2197)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2431)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2355)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2431)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2355)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:527)
# 	at sun.reflect.GeneratedMethodAccessor32.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2322)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2431)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2355)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2431)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2355)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:503)
# 	at java.io.ObjectInputStream.readObject(ObjectInputStream.java:461)
# 	at scala.collection.immutable.List$SerializationProxy.readObject(List.scala:527)
# 	at sun.reflect.GeneratedMethodAccessor32.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at java.io.ObjectStreamClass.invokeReadObject(ObjectStreamClass.java:1184)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2322)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# 	at java.io.ObjectInputStream.readObject0(ObjectInputStream.java:1669)
# 	at java.io.ObjectInputStream.defaultReadFields(ObjectInputStream.java:2431)
# 	at java.io.ObjectInputStream.readSerialData(ObjectInputStream.java:2355)
# 	at java.io.ObjectInputStream.readOrdinaryObject(ObjectInputStream.java:2213)
# ...
# 23/05/18 05:22:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:22:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:22:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:22:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:23:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:24:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:24:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:24:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:24:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:24:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:24:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:24:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:25:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:04:57.821158
# RMSE: 2.0988841828471374
# Iteration with 20 iterations, 0.1 regularization parameter, and 10 rank started at 2023-05-18 05:25:23.556076
# 23/05/18 05:26:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:26:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:26:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:26:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:26:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:27:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:28:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:29:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:29:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:30:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:30:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# Iteration completed in: 0:05:08.038727
# RMSE: 2.102552636495326
# Iteration with 20 iterations, 0.1 regularization parameter, and 20 rank started at 2023-05-18 05:30:31.594900
# 23/05/18 05:31:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:31:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:31:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:31:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:31:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:32:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:33:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 05:34:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:34:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:35:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 05:35:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# [Stage 3009:======================================>                (9 + 4) / 13]
# Iteration completed in: 0:04:57.928769
# RMSE: 2.1620951662303542

# %%
# create pyspark dataframe 
lOutputMetrics = [t[2:] for t in lOutput] 
dfOutput = spark.createDataFrame(data = lOutputMetrics, schema = ['Iterations', 'Rank', 'Reg', 'RMSE']) 
dfOutput = dfOutput.orderBy('RMSE', ascending = False) 
dfOutput.show()
# Out:
# +----------+----+----+------------------+
# |Iterations|Rank| Reg|              RMSE|
# +----------+----+----+------------------+
# |         5|   5|0.01| 4.771131906795268|
# |        10|   5|0.01|3.5876645090493025|
# |         5|  10|0.01| 2.986872199813267|
# |        20|   5|0.01|2.8005328616039136|
# |        10|  10|0.01|2.7376874848211012|
# |        20|  10|0.01|2.4848457217772286|
# |         5|  20|0.01|2.4237914716253877|
# |         5|   5| 0.1|2.3900637519277295|
# |        10|  20|0.01| 2.375280468596678|
# |         5|  10| 0.1| 2.314528139754796|
# |         5|  20| 0.1|2.3103115484588073|
# |        10|   5| 0.1|2.2504165539498673|
# |        10|  10| 0.1|2.2215463964345123|
# |        10|  20| 0.1| 2.189806000652578|
# |        20|  20|0.01|2.1717087398943455|
# |        20|  20| 0.1|2.1620951662303542|
# |        20|  10| 0.1| 2.102552636495326|
# |        20|   5| 0.1|2.0988841828471374|
# +----------+----+----+------------------+

# %%
# fit full model 

modFit, preds, RMSE = modelALS(dfALS, 'idx_user_id', 'idx_b_name', 'r_stars', sampleProp = 0.5, iters = 20, rank = 5, reg = 0.1)
# Out:
# 23/05/18 06:04:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:04:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:05:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:05:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:05:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:06:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:07:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:08:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:09:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:10:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:10:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.8 MiB
# 23/05/18 06:10:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 06:10:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 06:10:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB
# 23/05/18 06:11:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 54.9 MiB

# %%
# create functions to make predictions best model 

def getRecsForUser(model, subset, n = 3): 
    recs = model.recommendForUserSubset(subset, n) 
    return recs 

def getRecsForBusiness(model, subset, n = 3): 
    recs = model.recommendForItemSubset(subset, n) 
    return recs

# %%
print('RMSE:', RMSE)
# Out:
# RMSE: 1.1096681724421948

# %%
# implement a random forest classifier 
# selected because feature selection is generally not very important
