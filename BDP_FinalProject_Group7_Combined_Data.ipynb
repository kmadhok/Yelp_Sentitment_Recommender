# %% [markdown]
# #### Yelp Recommender Dataset Creation

# %%
from pyspark.sql import SparkSession 

spark = SparkSession.builder.appName('Yelp Restaurant Recommender').getOrCreate()
sc = spark.sparkContext

# %%
# read in yelp datasets 
dfBusiness = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/business.snappy.parquet')
dfReview = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/review.snappy.parquet')
dfUser = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/user.snappy.parquet') 

# read in Daisuke's sentiment analysis model output 
dfSentiment = spark.read.option('multiline','true').option("quote", "\"").option('escape','\"').option('ignoreLeadingWhiteSpace', 'true').option('header', True).option('escapeQuotes', 'true').parquet('gs://msca-bdp-student-gcs/GroupProject_Gr7/yelp_dataset/engineered_data/aspect_sentiment.snappy.parquet')

# %%
# for presentation example 
dfBusiness.filter("GoodForMeal not like '%u'''").select('business_id', 'GoodForMeal').show(1, truncate = False) # eEOYSgkmpB90uNA7lDOMRA
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +----------------------+------------------------------------------------------------------------------------------------------------+
# |business_id           |GoodForMeal                                                                                                 |
# +----------------------+------------------------------------------------------------------------------------------------------------+
# |eEOYSgkmpB90uNA7lDOMRA|{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}|
# +----------------------+------------------------------------------------------------------------------------------------------------+
# only showing top 1 row

# %%
from pyspark.sql import functions as F 

# create partition function from professor 
def displayPartitions(df): 
    num = df.rdd.getNumPartitions() 
    df.withColumn('partitionId', F.spark_partition_id()).groupby('partitionId').count().orderBy(F.asc('count')).show(num)

# %% [raw]
# # clean business data
#
# # unwrap nested struct columns
#
# dfBusiness = dfBusiness.withColumn('AcceptsInsurance', F.col('attributes.AcceptsInsurance'))
# dfBusiness = dfBusiness.withColumn('AgesAllowed', F.col('attributes.AgesAllowed'))
# dfBusiness = dfBusiness.withColumn('Alcohol', F.col('attributes.Alcohol'))
# dfBusiness = dfBusiness.withColumn('Ambience', F.col('attributes.Ambience'))
# dfBusiness = dfBusiness.withColumn('BYOB', F.col('attributes.BYOB'))
# dfBusiness = dfBusiness.withColumn('BYOBCorkage', F.col('attributes.BYOBCorkage'))
# dfBusiness = dfBusiness.withColumn('BestNights', F.col('attributes.BestNights'))
# dfBusiness = dfBusiness.withColumn('BikeParking', F.col('attributes.BikeParking'))
# dfBusiness = dfBusiness.withColumn('BusinessAcceptsBitcoin', F.col('attributes.BusinessAcceptsBitcoin'))
# dfBusiness = dfBusiness.withColumn('BusinessAcceptsCreditCards', F.col('attributes.BusinessAcceptsCreditCards'))
# dfBusiness = dfBusiness.withColumn('BusinessParking', F.col('attributes.BusinessParking'))
# dfBusiness = dfBusiness.withColumn('ByAppointmentOnly', F.col('attributes.ByAppointmentOnly'))
# dfBusiness = dfBusiness.withColumn('Caters', F.col('attributes.Caters'))
# dfBusiness = dfBusiness.withColumn('CoatCheck', F.col('attributes.CoatCheck'))
# dfBusiness = dfBusiness.withColumn('Corkage', F.col('attributes.Corkage'))
# dfBusiness = dfBusiness.withColumn('DietaryRestrictions', F.col('attributes.DietaryRestrictions'))
# dfBusiness = dfBusiness.withColumn('DogsAllowed', F.col('attributes.DogsAllowed'))
# dfBusiness = dfBusiness.withColumn('DriveThru', F.col('attributes.DriveThru'))
# dfBusiness = dfBusiness.withColumn('GoodForDancing', F.col('attributes.GoodForDancing'))
# dfBusiness = dfBusiness.withColumn('GoodForKids', F.col('attributes.GoodForKids'))
# dfBusiness = dfBusiness.withColumn('GoodForMeal', F.col('attributes.GoodForMeal'))
# dfBusiness = dfBusiness.withColumn('HairSpecializesIn', F.col('attributes.HairSpecializesIn'))
# dfBusiness = dfBusiness.withColumn('HappyHour', F.col('attributes.HappyHour'))
# dfBusiness = dfBusiness.withColumn('HasTV', F.col('attributes.HasTV'))
# dfBusiness = dfBusiness.withColumn('Music', F.col('attributes.Music'))
# dfBusiness = dfBusiness.withColumn('NoiseLevel', F.col('attributes.NoiseLevel'))
# dfBusiness = dfBusiness.withColumn('Open24Hours', F.col('attributes.Open24Hours'))
# dfBusiness = dfBusiness.withColumn('OutdoorSeating', F.col('attributes.OutdoorSeating'))
# dfBusiness = dfBusiness.withColumn('RestaurantsAttire', F.col('attributes.RestaurantsAttire'))
# dfBusiness = dfBusiness.withColumn('RestaurantsCounterService', F.col('attributes.RestaurantsCounterService'))
# dfBusiness = dfBusiness.withColumn('RestaurantsDelivery', F.col('attributes.RestaurantsDelivery'))
# dfBusiness = dfBusiness.withColumn('RestaurantsGoodForGroups', F.col('attributes.RestaurantsGoodForGroups'))
# dfBusiness = dfBusiness.withColumn('RestaurantsPriceRange2', F.col('attributes.RestaurantsPriceRange2'))
# dfBusiness = dfBusiness.withColumn('RestaurantsReservations', F.col('attributes.RestaurantsReservations'))
# dfBusiness = dfBusiness.withColumn('RestaurantsTableService', F.col('attributes.RestaurantsTableService'))
# dfBusiness = dfBusiness.withColumn('RestaurantsTakeOut', F.col('attributes.RestaurantsTakeOut'))
# dfBusiness = dfBusiness.withColumn('Smoking', F.col('attributes.Smoking'))
# dfBusiness = dfBusiness.withColumn('WheelchairAccessible', F.col('attributes.WheelchairAccessible'))
# dfBusiness = dfBusiness.withColumn('WiFi', F.col('attributes.WiFi'))
#
# dfBusiness = dfBusiness.withColumn('Friday', F.col('hours.Friday'))
# dfBusiness = dfBusiness.withColumn('Monday', F.col('hours.Monday'))
# dfBusiness = dfBusiness.withColumn('Saturday', F.col('hours.Saturday'))
# dfBusiness = dfBusiness.withColumn('Sunday', F.col('hours.Sunday'))
# dfBusiness = dfBusiness.withColumn('Thursday', F.col('hours.Thursday'))
# dfBusiness = dfBusiness.withColumn('Tuesday', F.col('hours.Tuesday'))
# dfBusiness = dfBusiness.withColumn('Wednesday', F.col('hours.Wednesday'))
#
# dfBusiness = dfBusiness.drop('attributes', 'hours')

# %%
from pyspark.sql.functions import col, desc, when, regexp_replace, regexp_extract, explode 
from pyspark.sql.types import StringType, MapType, IntegerType 
from ast import literal_eval 

# clean business data (cont.) 

# drop any unnecessary fields 
dfBusiness = dfBusiness.drop('AcceptsInsurance', 'HairSpecializesIn')

# for each newly created column show the top distinct values and make necessary adjustments 
# for colName in dfBusiness.columns[12:]: 
    # dfBusiness.groupby(colName).count().withColumnRenamed('count', 'businesses').sort(col('businesses').desc()).show(25) 


# convert different string types to same value     
dfBusiness = dfBusiness.withColumn('AgesAllowed', F.when(col('AgesAllowed') == u'allages', 'allages').when(col('AgesAllowed') == u'21plus', '21plus').otherwise(col('AgesAllowed'))) 
dfBusiness = dfBusiness.withColumn('Alcohol', F.when(col('Alcohol') == u'none', 'none').when(col('Alcohol') == u'full_bar', 'full_bar').when(col('Alcohol') == u'beer_and_wine', 'beer_and_wine').otherwise(col('Alcohol'))) 
dfBusiness = dfBusiness.withColumn('BYOBCorkage', F.when(col('BYOBCorkage') == u'no', 'no').when(col('BYOBCorkage') == u'yes', 'yes').when(col('BYOBCorkage') == u'yes_corkage', 'yes_corkage').otherwise(col('BYOBCorkage'))) 
dfBusiness = dfBusiness.withColumn('NoiseLevel', F.when(col('NoiseLevel') == u'average', 'average').when(col('NoiseLevel') == u'quiet', 'quiet').when(col('NoiseLevel') == u'loud', 'loud').when(col('NoiseLevel') == u'very_loud', 'very_loud').otherwise(col('NoiseLevel'))) 
dfBusiness = dfBusiness.withColumn('RestaurantsAttire', F.when(col('RestaurantsAttire') == u'casual', 'casual').when(col('RestaurantsAttire') == u'dressy', 'dressy').when(col('RestaurantsAttire') == u'formal', 'formal').otherwise(col('RestaurantsAttire'))) 
dfBusiness = dfBusiness.withColumn('Smoking', F.when(col('Smoking') == u'no', 'no').when(col('Smoking') == u'outdoor', 'outdoor').when(col('Smoking') == u'yes', 'yes').otherwise(col('Smoking'))) 
dfBusiness = dfBusiness.withColumn('WiFi', F.when(col('WiFi') == u'no', 'no').when(col('WiFi') == u'free', 'free').when(col('WiFi') == u'paid', 'paid').otherwise(col('WiFi'))) 

# convert any None or null to unknown 
dfBusiness = dfBusiness.replace('None', None) 
dfBusiness = dfBusiness.na.fill('unknown') 

# unnest further nested columns 
dfBusinessNestedCols = ['Ambience', 'BestNights', 'BusinessParking', 'DietaryRestrictions', 'GoodForMeal', 'Music'] 
for column in dfBusinessNestedCols: 
    dfBusiness = dfBusiness.withColumn('clean{}'.format(column), regexp_replace(column, "u'", "'")) 
    dfBusiness = dfBusiness.withColumn('clean{}'.format(column), regexp_replace(column, 'unknown', "{'unknown': True}")) 
    dfBusiness = dfBusiness.withColumn(column, F.udf(literal_eval, 'map<string,string>')('clean{}'.format(column))) 
    dfBusiness = dfBusiness.drop('clean{}'.format(column)) 
    curKeys = (dfBusiness.select(explode(column)).select('key').distinct().rdd.flatMap(lambda x: x).collect()) 
    curExpressions = [col(column).getItem(k).alias('{}_{}'.format(column, k)) for k in curKeys] 
    dfBusiness = dfBusiness.select('*', *curExpressions).drop(column) 

# create open/close for each time 
dfBusinessHoursCols = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'] 
for column in dfBusinessHoursCols: 
    dfBusiness = dfBusiness.select('*', F.when(col(column) != 'unknown', regexp_extract(column, r'.*?(?=\:)', 0)).otherwise(None).alias('{}_start_str'.format(column)))
    dfBusiness = dfBusiness.select('*', F.when(col(column) != 'unknown', regexp_extract(column, r'(?<=\-).+(?=\:)', 0)).otherwise(None).alias('{}_end_str'.format(column)))
    dfBusiness = dfBusiness.withColumn('{}_start'.format(column), col('{}_start_str'.format(column)).cast(IntegerType())) 
    dfBusiness = dfBusiness.withColumn('{}_end'.format(column), col('{}_end_str'.format(column)).cast(IntegerType()))
    dfBusiness = dfBusiness.drop(column, '{}_start_str'.format(column), '{}_end_str'.format(column)) 

dfBusiness.printSchema()
# Out:
# root
#  |-- address: string (nullable = false)
#  |-- business_id: string (nullable = false)
#  |-- categories: string (nullable = false)
#  |-- city: string (nullable = false)
#  |-- is_open: long (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- name: string (nullable = false)
#  |-- postal_code: string (nullable = false)
#  |-- review_count: long (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- state: string (nullable = false)
#  |-- AgesAllowed: string (nullable = false)
#  |-- Alcohol: string (nullable = false)
#  |-- BYOB: string (nullable = false)
#  |-- BYOBCorkage: string (nullable = false)
#  |-- BikeParking: string (nullable = false)
#  |-- BusinessAcceptsBitcoin: string (nullable = false)
#  |-- BusinessAcceptsCreditCards: string (nullable = false)
#  |-- ByAppointmentOnly: string (nullable = false)
#  |-- Caters: string (nullable = false)
#  |-- CoatCheck: string (nullable = false)
#  |-- Corkage: string (nullable = false)
#  |-- DogsAllowed: string (nullable = false)
#  |-- DriveThru: string (nullable = false)
#  |-- GoodForDancing: string (nullable = false)
#  |-- GoodForKids: string (nullable = false)
#  |-- HappyHour: string (nullable = false)
#  |-- HasTV: string (nullable = false)
#  |-- NoiseLevel: string (nullable = false)
#  |-- Open24Hours: string (nullable = false)
#  |-- OutdoorSeating: string (nullable = false)
#  |-- RestaurantsAttire: string (nullable = false)
#  |-- RestaurantsCounterService: string (nullable = false)
#  |-- RestaurantsDelivery: string (nullable = false)
#  |-- RestaurantsGoodForGroups: string (nullable = false)
#  |-- RestaurantsPriceRange2: string (nullable = false)
#  |-- RestaurantsReservations: string (nullable = false)
#  |-- RestaurantsTableService: string (nullable = false)
#  |-- RestaurantsTakeOut: string (nullable = false)
#  |-- Smoking: string (nullable = false)
#  |-- WheelchairAccessible: string (nullable = false)
#  |-- WiFi: string (nullable = false)
#  |-- Ambience_romantic: string (nullable = true)
#  |-- Ambience_unknown: string (nullable = true)
#  |-- Ambience_casual: string (nullable = true)
#  |-- Ambience_trendy: string (nullable = true)
#  |-- Ambience_intimate: string (nullable = true)
#  |-- Ambience_hipster: string (nullable = true)
#  |-- Ambience_upscale: string (nullable = true)
#  |-- Ambience_divey: string (nullable = true)
#  |-- Ambience_touristy: string (nullable = true)
#  |-- Ambience_classy: string (nullable = true)
#  |-- BestNights_unknown: string (nullable = true)
#  |-- BestNights_sunday: string (nullable = true)
#  |-- BestNights_thursday: string (nullable = true)
#  |-- BestNights_monday: string (nullable = true)
#  |-- BestNights_wednesday: string (nullable = true)
#  |-- BestNights_saturday: string (nullable = true)
#  |-- BestNights_friday: string (nullable = true)
#  |-- BestNights_tuesday: string (nullable = true)
#  |-- BusinessParking_unknown: string (nullable = true)
#  |-- BusinessParking_valet: string (nullable = true)
#  |-- BusinessParking_lot: string (nullable = true)
#  |-- BusinessParking_validated: string (nullable = true)
#  |-- BusinessParking_garage: string (nullable = true)
#  |-- BusinessParking_street: string (nullable = true)
#  |-- DietaryRestrictions_kosher: string (nullable = true)
#  |-- DietaryRestrictions_unknown: string (nullable = true)
#  |-- DietaryRestrictions_dairy-free: string (nullable = true)
#  |-- DietaryRestrictions_vegan: string (nullable = true)
#  |-- DietaryRestrictions_vegetarian: string (nullable = true)
#  |-- DietaryRestrictions_gluten-free: string (nullable = true)
#  |-- DietaryRestrictions_soy-free: string (nullable = true)
#  |-- DietaryRestrictions_halal: string (nullable = true)
#  |-- GoodForMeal_lunch: string (nullable = true)
#  |-- GoodForMeal_unknown: string (nullable = true)
#  |-- GoodForMeal_brunch: string (nullable = true)
#  |-- GoodForMeal_dinner: string (nullable = true)
#  |-- GoodForMeal_latenight: string (nullable = true)
#  |-- GoodForMeal_dessert: string (nullable = true)
#  |-- GoodForMeal_breakfast: string (nullable = true)
#  |-- Music_unknown: string (nullable = true)
#  |-- Music_no_music: string (nullable = true)
#  |-- Music_dj: string (nullable = true)
#  |-- Music_live: string (nullable = true)
#  |-- Music_karaoke: string (nullable = true)
#  |-- Music_video: string (nullable = true)
#  |-- Music_background_music: string (nullable = true)
#  |-- Music_jukebox: string (nullable = true)
#  |-- Monday_start: integer (nullable = true)
#  |-- Monday_end: integer (nullable = true)
#  |-- Tuesday_start: integer (nullable = true)
#  |-- Tuesday_end: integer (nullable = true)
#  |-- Wednesday_start: integer (nullable = true)
#  |-- Wednesday_end: integer (nullable = true)
#  |-- Thursday_start: integer (nullable = true)
#  |-- Thursday_end: integer (nullable = true)
#  |-- Friday_start: integer (nullable = true)
#  |-- Friday_end: integer (nullable = true)
#  |-- Saturday_start: integer (nullable = true)
#  |-- Saturday_end: integer (nullable = true)
#  |-- Sunday_start: integer (nullable = true)
#  |-- Sunday_end: integer (nullable = true)

# %%
# clean reviews data 

from pyspark.sql.functions import col, to_date, to_timestamp 
from pyspark.sql.functions import year, month, dayofweek, hour 
from pyspark.sql.functions import length 

# convert date field to actual date 
dfReview = dfReview.withColumn('datetime', to_timestamp(col('date'), 'yyyy-MM-dd HH:mm:ss')) 
dfReview = dfReview.withColumn('date', to_date(col('datetime'))) 

# create date-related fields 
dfReview = dfReview.withColumn('year', year(col('date'))).withColumn('month', month(col('date'))) 
dfReview = dfReview.withColumn('day', dayofweek(col('date'))) 
dfReview = dfReview.withColumn('hour', hour(col('datetime'))) 

# create length of review field 
dfReview = dfReview.withColumn('text_length', length(col('text'))) 

dfReview.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- date: date (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- text_length: integer (nullable = true)

# %%
from pyspark.sql.functions import size, split 

# clean user data 

dfUser = dfUser.withColumn('yelping_since', to_timestamp(col('yelping_since'), 'yyyy-MM-dd HH:mm:ss')) 

dfUser = dfUser.replace('None', None) 
dfUser = dfUser.na.fill('unknown') 
dfUser = dfUser.withColumn('n_friends', F.when(col('friends') == 'unknown', 0).otherwise(size(split(col('friends'), r'\,'))))
dfUser = dfUser.drop('name', 'friends') 

dfUser.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = false)
#  |-- average_stars: double (nullable = true)
#  |-- compliment_cool: long (nullable = true)
#  |-- compliment_cute: long (nullable = true)
#  |-- compliment_funny: long (nullable = true)
#  |-- compliment_hot: long (nullable = true)
#  |-- compliment_list: long (nullable = true)
#  |-- compliment_more: long (nullable = true)
#  |-- compliment_note: long (nullable = true)
#  |-- compliment_photos: long (nullable = true)
#  |-- compliment_plain: long (nullable = true)
#  |-- compliment_profile: long (nullable = true)
#  |-- compliment_writer: long (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- elite: string (nullable = false)
#  |-- fans: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- yelping_since: timestamp (nullable = true)
#  |-- n_friends: integer (nullable = false)

# %%
# clean sentiment data 

# confirm counts are similar between sentiment and review 
dfSentiment.count() # 3773770
dfReview.count() # 3773770 
# good! 

dfSentiment.printSchema() # already good thanks to Daisuke!
# Out:
# [Stage 26:==========================================>              (9 + 2) / 12]
# root
#  |-- review_id: string (nullable = true)
#  |-- Price_total: long (nullable = true)
#  |-- Opinion_total: long (nullable = true)
#  |-- Food_total: long (nullable = true)
#  |-- Atmosphere_total: long (nullable = true)
#  |-- Service_total: long (nullable = true)
#  |-- Total_sentscore: double (nullable = true)
#  |-- Price_sentscore: double (nullable = true)
#  |-- Opinion_sentscore: double (nullable = true)
#  |-- Food_sentscore: double (nullable = true)
#  |-- Atmosphere_sentscore: double (nullable = true)
#  |-- Service_sentscore: double (nullable = true)
#  |-- Sentence_num: long (nullable = true)

# %%
# repartition if necessary 

print('Default parallelism:', sc.defaultParallelism, '\n')

print('Number of dfBusiness partitions:', dfBusiness.rdd.getNumPartitions()) 
print('Number of dfReview partitions:', dfReview.rdd.getNumPartitions()) 
print('Number of dfSentiment partitions:', dfSentiment.rdd.getNumPartitions()) 
print('Number of dfUser partitions:', dfUser.rdd.getNumPartitions()) 

# good for now, but will want to repartition the final table
# Out:
# Default parallelism: 2
#
# Number of dfBusiness partitions: 1
# Number of dfReview partitions: 12
# Number of dfSentiment partitions: 2
# Number of dfUser partitions: 14

# %%
import numpy as np 

# rename the columns in each table and join together 

dfBusinessColumns = [str(np.where(col[-3:] != '_id', 'b_{}'.format(col), col)) for col in dfBusiness.columns] 
dfBusiness = dfBusiness.toDF(*dfBusinessColumns) 
dfReviewColumns = [str(np.where(col[-3:] != '_id', 'r_{}'.format(col), col)) for col in dfReview.columns]
dfReview = dfReview.toDF(*dfReviewColumns) 
dfSentimentColumns = [str(np.where(col[-3:] != '_id', 's_{}'.format(col), col)) for col in dfSentiment.columns]
dfSentiment = dfSentiment.toDF(*dfSentimentColumns) 
dfUserColumns = [str(np.where(col[-3:] != '_id', 'u_{}'.format(col), col)) for col in dfUser.columns]
dfUser = dfUser.toDF(*dfUserColumns) 

dfFinal = dfReview.join(dfBusiness, 'business_id', 'left').join(dfSentiment, 'review_id', 'left').join(dfUser, 'user_id', 'left')

# %%
dfFinal.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- r_cool: long (nullable = true)
#  |-- r_date: date (nullable = true)
#  |-- r_funny: long (nullable = true)
#  |-- r_stars: double (nullable = true)
#  |-- r_text: string (nullable = true)
#  |-- r_useful: long (nullable = true)
#  |-- r_datetime: timestamp (nullable = true)
#  |-- r_year: integer (nullable = true)
#  |-- r_month: integer (nullable = true)
#  |-- r_day: integer (nullable = true)
#  |-- r_hour: integer (nullable = true)
#  |-- r_text_length: integer (nullable = true)
#  |-- b_address: string (nullable = true)
#  |-- b_categories: string (nullable = true)
#  |-- b_city: string (nullable = true)
#  |-- b_is_open: long (nullable = true)
#  |-- b_latitude: double (nullable = true)
#  |-- b_longitude: double (nullable = true)
#  |-- b_name: string (nullable = true)
#  |-- b_postal_code: string (nullable = true)
#  |-- b_review_count: long (nullable = true)
#  |-- b_stars: double (nullable = true)
#  |-- b_state: string (nullable = true)
#  |-- b_AgesAllowed: string (nullable = true)
#  |-- b_Alcohol: string (nullable = true)
#  |-- b_BYOB: string (nullable = true)
#  |-- b_BYOBCorkage: string (nullable = true)
#  |-- b_BikeParking: string (nullable = true)
#  |-- b_BusinessAcceptsBitcoin: string (nullable = true)
#  |-- b_BusinessAcceptsCreditCards: string (nullable = true)
#  |-- b_ByAppointmentOnly: string (nullable = true)
#  |-- b_Caters: string (nullable = true)
#  |-- b_CoatCheck: string (nullable = true)
#  |-- b_Corkage: string (nullable = true)
#  |-- b_DogsAllowed: string (nullable = true)
#  |-- b_DriveThru: string (nullable = true)
#  |-- b_GoodForDancing: string (nullable = true)
#  |-- b_GoodForKids: string (nullable = true)
#  |-- b_HappyHour: string (nullable = true)
#  |-- b_HasTV: string (nullable = true)
#  |-- b_NoiseLevel: string (nullable = true)
#  |-- b_Open24Hours: string (nullable = true)
#  |-- b_OutdoorSeating: string (nullable = true)
#  |-- b_RestaurantsAttire: string (nullable = true)
#  |-- b_RestaurantsCounterService: string (nullable = true)
#  |-- b_RestaurantsDelivery: string (nullable = true)
#  |-- b_RestaurantsGoodForGroups: string (nullable = true)
#  |-- b_RestaurantsPriceRange2: string (nullable = true)
#  |-- b_RestaurantsReservations: string (nullable = true)
#  |-- b_RestaurantsTableService: string (nullable = true)
#  |-- b_RestaurantsTakeOut: string (nullable = true)
#  |-- b_Smoking: string (nullable = true)
#  |-- b_WheelchairAccessible: string (nullable = true)
#  |-- b_WiFi: string (nullable = true)
#  |-- b_Ambience_romantic: string (nullable = true)
#  |-- b_Ambience_unknown: string (nullable = true)
#  |-- b_Ambience_casual: string (nullable = true)
#  |-- b_Ambience_trendy: string (nullable = true)
#  |-- b_Ambience_intimate: string (nullable = true)
#  |-- b_Ambience_hipster: string (nullable = true)
#  |-- b_Ambience_upscale: string (nullable = true)
#  |-- b_Ambience_divey: string (nullable = true)
#  |-- b_Ambience_touristy: string (nullable = true)
#  |-- b_Ambience_classy: string (nullable = true)
#  |-- b_BestNights_unknown: string (nullable = true)
#  |-- b_BestNights_sunday: string (nullable = true)
#  |-- b_BestNights_thursday: string (nullable = true)
#  |-- b_BestNights_monday: string (nullable = true)
#  |-- b_BestNights_wednesday: string (nullable = true)
#  |-- b_BestNights_saturday: string (nullable = true)
#  |-- b_BestNights_friday: string (nullable = true)
#  |-- b_BestNights_tuesday: string (nullable = true)
#  |-- b_BusinessParking_unknown: string (nullable = true)
#  |-- b_BusinessParking_valet: string (nullable = true)
#  |-- b_BusinessParking_lot: string (nullable = true)
#  |-- b_BusinessParking_validated: string (nullable = true)
#  |-- b_BusinessParking_garage: string (nullable = true)
#  |-- b_BusinessParking_street: string (nullable = true)
#  |-- b_DietaryRestrictions_kosher: string (nullable = true)
#  |-- b_DietaryRestrictions_unknown: string (nullable = true)
#  |-- b_DietaryRestrictions_dairy-free: string (nullable = true)
#  |-- b_DietaryRestrictions_vegan: string (nullable = true)
#  |-- b_DietaryRestrictions_vegetarian: string (nullable = true)
#  |-- b_DietaryRestrictions_gluten-free: string (nullable = true)
#  |-- b_DietaryRestrictions_soy-free: string (nullable = true)
#  |-- b_DietaryRestrictions_halal: string (nullable = true)
#  |-- b_GoodForMeal_lunch: string (nullable = true)
#  |-- b_GoodForMeal_unknown: string (nullable = true)
#  |-- b_GoodForMeal_brunch: string (nullable = true)
#  |-- b_GoodForMeal_dinner: string (nullable = true)
#  |-- b_GoodForMeal_latenight: string (nullable = true)
#  |-- b_GoodForMeal_dessert: string (nullable = true)
#  |-- b_GoodForMeal_breakfast: string (nullable = true)
#  |-- b_Music_unknown: string (nullable = true)
#  |-- b_Music_no_music: string (nullable = true)
#  |-- b_Music_dj: string (nullable = true)
#  |-- b_Music_live: string (nullable = true)
#  |-- b_Music_karaoke: string (nullable = true)
#  |-- b_Music_video: string (nullable = true)
#  |-- b_Music_background_music: string (nullable = true)
#  |-- b_Music_jukebox: string (nullable = true)
#  |-- b_Monday_start: integer (nullable = true)
#  |-- b_Monday_end: integer (nullable = true)
#  |-- b_Tuesday_start: integer (nullable = true)
#  |-- b_Tuesday_end: integer (nullable = true)
#  |-- b_Wednesday_start: integer (nullable = true)
#  |-- b_Wednesday_end: integer (nullable = true)
#  |-- b_Thursday_start: integer (nullable = true)
#  |-- b_Thursday_end: integer (nullable = true)
#  |-- b_Friday_start: integer (nullable = true)
#  |-- b_Friday_end: integer (nullable = true)
#  |-- b_Saturday_start: integer (nullable = true)
#  |-- b_Saturday_end: integer (nullable = true)
#  |-- b_Sunday_start: integer (nullable = true)
#  |-- b_Sunday_end: integer (nullable = true)
#  |-- s_Price_total: long (nullable = true)
#  |-- s_Opinion_total: long (nullable = true)
#  |-- s_Food_total: long (nullable = true)
#  |-- s_Atmosphere_total: long (nullable = true)
#  |-- s_Service_total: long (nullable = true)
#  |-- s_Total_sentscore: double (nullable = true)
#  |-- s_Price_sentscore: double (nullable = true)
#  |-- s_Opinion_sentscore: double (nullable = true)
#  |-- s_Food_sentscore: double (nullable = true)
#  |-- s_Atmosphere_sentscore: double (nullable = true)
#  |-- s_Service_sentscore: double (nullable = true)
#  |-- s_Sentence_num: long (nullable = true)
#  |-- u_average_stars: double (nullable = true)
#  |-- u_compliment_cool: long (nullable = true)
#  |-- u_compliment_cute: long (nullable = true)
#  |-- u_compliment_funny: long (nullable = true)
#  |-- u_compliment_hot: long (nullable = true)
#  |-- u_compliment_list: long (nullable = true)
#  |-- u_compliment_more: long (nullable = true)
#  |-- u_compliment_note: long (nullable = true)
#  |-- u_compliment_photos: long (nullable = true)
#  |-- u_compliment_plain: long (nullable = true)
#  |-- u_compliment_profile: long (nullable = true)
#  |-- u_compliment_writer: long (nullable = true)
#  |-- u_cool: long (nullable = true)
#  |-- u_elite: string (nullable = true)
#  |-- u_fans: long (nullable = true)
#  |-- u_funny: long (nullable = true)
#  |-- u_review_count: long (nullable = true)
#  |-- u_useful: long (nullable = true)
#  |-- u_yelping_since: timestamp (nullable = true)
#  |-- u_n_friends: integer (nullable = true)

# %%
# repartition the dataset 

print('Default parallelism:', sc.defaultParallelism, '\n')
print('Number of dfFinal partitions:', dfFinal.rdd.getNumPartitions(), '\n') 

dfFinal = dfFinal.repartition(200)
# displayPartitions(dfFinal)
# Out:
# Default parallelism: 2
# [Stage 35:======================================================> (93 + 2) / 95]
# Number of dfFinal partitions: 89

# %%
# for presentation example 
dfBusiness.filter("business_id = 'eEOYSgkmpB90uNA7lDOMRA'").select('b_GoodForMeal_lunch', 'b_GoodForMeal_unknown', 'b_GoodForMeal_brunch', 'b_GoodForMeal_dinner', 'b_GoodForMeal_latenight', 'b_GoodForMeal_dessert', 'b_GoodForMeal_breakfast').show(1, truncate = False)
# Out:
# +-------------------+---------------------+--------------------+--------------------+-----------------------+---------------------+-----------------------+
# |b_GoodForMeal_lunch|b_GoodForMeal_unknown|b_GoodForMeal_brunch|b_GoodForMeal_dinner|b_GoodForMeal_latenight|b_GoodForMeal_dessert|b_GoodForMeal_breakfast|
# +-------------------+---------------------+--------------------+--------------------+-----------------------+---------------------+-----------------------+
# |false              |null                 |false               |false               |false                  |false                |false                  |
# +-------------------+---------------------+--------------------+--------------------+-----------------------+---------------------+-----------------------+
